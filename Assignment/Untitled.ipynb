# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
from sklearn.cross_validation import train_test_split
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-ea24c5b8272e> in <module>
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 from sklearn import linear_model
#       4 from sklearn.cross_validation import train_test_split
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
 self.boston = pd.read_csv(./housing.csv, sep='\t')
# Out:
#   File "<ipython-input-2-fa590bc24627>", line 1
#     self.boston = pd.read_csv(./housing.csv, sep='\t')
#                               ^
# SyntaxError: invalid syntax

# %%
self.boston = pd.read_csv("./housing.csv", sep='\t')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-aaa9f96c1608> in <module>
# ----> 1 self.boston = pd.read_csv("./housing.csv", sep='\t')
#
# NameError: name 'self' is not defined

# %%
boston = pd.read_csv(./housing.csv, sep='\t')
# Out:
#   File "<ipython-input-4-a14ebc007746>", line 1
#     boston = pd.read_csv(./housing.csv, sep='\t')
#                          ^
# SyntaxError: invalid syntax

# %%
boston = pd.read_csv("./housing.csv", sep='\t')

# %%
boston
# Out:
#      0.00632  18.00   2.310  0  0.5380  6.5750  65.20  4.0900   1  296.0  15.30 396.90   4.98  24.00
# 0     0.02731   0.00   7.070  0  0.4690  6.4210  78...
# 1     0.02729   0.00   7.070  0  0.4690  7.1850  61...
# 2     0.03237   0.00   2.180  0  0.4580  6.9980  45...
# 3     0.06905   0.00   2.180  0  0.4580  7.1470  54...
# 4     0.02985   0.00   2.180  0  0.4580  6.4300  58...
# ..                                                 ...
# 500   0.06263   0.00  11.930  0  0.5730  6.5930  69...
# 501   0.04527   0.00  11.930  0  0.5730  6.1200  76...
# 502   0.06076   0.00  11.930  0  0.5730  6.9760  91...
# 503   0.10959   0.00  11.930  0  0.5730  6.7940  89...
# 504   0.04741   0.00  11.930  0  0.5730  6.0300  80...
#
# [505 rows x 1 columns]

# %%
df= pd.DataFrame(boston)

# %%
boston = pd.read_csv("./housing.csv", header=none)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-8d92aa6a214a> in <module>
# ----> 1 boston = pd.read_csv("./housing.csv", header=none)
#
# NameError: name 'none' is not defined

# %%
boston = pd.read_csv("./housing.csv", header=None)

# %%
boston
# Out:
#                                                      0
# 0     0.00632  18.00   2.310  0  0.5380  6.5750  65...
# 1     0.02731   0.00   7.070  0  0.4690  6.4210  78...
# 2     0.02729   0.00   7.070  0  0.4690  7.1850  61...
# 3     0.03237   0.00   2.180  0  0.4580  6.9980  45...
# 4     0.06905   0.00   2.180  0  0.4580  7.1470  54...
# ..                                                 ...
# 501   0.06263   0.00  11.930  0  0.5730  6.5930  69...
# 502   0.04527   0.00  11.930  0  0.5730  6.1200  76...
# 503   0.06076   0.00  11.930  0  0.5730  6.9760  91...
# 504   0.10959   0.00  11.930  0  0.5730  6.7940  89...
# 505   0.04741   0.00  11.930  0  0.5730  6.0300  80...
#
# [506 rows x 1 columns]

# %%
df= pd.DataFrame(boston)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       506 non-null    object
# dtypes: object(1)
# memory usage: 4.1+ KB

# %%
boston.columns = ['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT','MEDV']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-be9696018aaa> in <module>
# ----> 1 boston.columns = ['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT','MEDV']
#
# /usr/local/Cellar/jupyterlab/3.0.7/libexec/lib/python3.9/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5473         try:
#    5474             object.__getattribute__(self, name)
# -> 5475             return object.__setattr__(self, name, value)
#    5476         except AttributeError:
#    5477             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# /usr/local/Cellar/jupyterlab/3.0.7/libexec/lib/python3.9/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     667     def _set_axis(self, axis: int, labels: Index) -> None:
#     668         labels = ensure_index(labels)
# ...

# %%
boston = pd.read_csv(./housing.csv, sep='\t')
# Out:
#   File "<ipython-input-14-a14ebc007746>", line 1
#     boston = pd.read_csv(./housing.csv, sep='\t')
#                          ^
# SyntaxError: invalid syntax

# %%
boston = pd.read_csv(''./housing.csv', sep='\t')
# Out:
#   File "<ipython-input-15-98df33bbab16>", line 1
#     boston = pd.read_csv(''./housing.csv', sep='\t')
#                             ^
# SyntaxError: invalid syntax

# %%
boston = pd.read_csv('./housing.csv', sep='\t')

# %%
boston.columns = ['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT','MEDV']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-be9696018aaa> in <module>
# ----> 1 boston.columns = ['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT','MEDV']
#
# /usr/local/Cellar/jupyterlab/3.0.7/libexec/lib/python3.9/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5473         try:
#    5474             object.__getattribute__(self, name)
# -> 5475             return object.__setattr__(self, name, value)
#    5476         except AttributeError:
#    5477             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# /usr/local/Cellar/jupyterlab/3.0.7/libexec/lib/python3.9/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     667     def _set_axis(self, axis: int, labels: Index) -> None:
#     668         labels = ensure_index(labels)
# ...

# %%
boston
# Out:
#      0.00632  18.00   2.310  0  0.5380  6.5750  65.20  4.0900   1  296.0  15.30 396.90   4.98  24.00
# 0     0.02731   0.00   7.070  0  0.4690  6.4210  78...
# 1     0.02729   0.00   7.070  0  0.4690  7.1850  61...
# 2     0.03237   0.00   2.180  0  0.4580  6.9980  45...
# 3     0.06905   0.00   2.180  0  0.4580  7.1470  54...
# 4     0.02985   0.00   2.180  0  0.4580  6.4300  58...
# ..                                                 ...
# 500   0.06263   0.00  11.930  0  0.5730  6.5930  69...
# 501   0.04527   0.00  11.930  0  0.5730  6.1200  76...
# 502   0.06076   0.00  11.930  0  0.5730  6.9760  91...
# 503   0.10959   0.00  11.930  0  0.5730  6.7940  89...
# 504   0.04741   0.00  11.930  0  0.5730  6.0300  80...
#
# [505 rows x 1 columns]

# %%
boston = pd.read_csv('./housing.csv')

# %%
boston.columns = ['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT','MEDV']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-be9696018aaa> in <module>
# ----> 1 boston.columns = ['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT','MEDV']
#
# /usr/local/Cellar/jupyterlab/3.0.7/libexec/lib/python3.9/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5473         try:
#    5474             object.__getattribute__(self, name)
# -> 5475             return object.__setattr__(self, name, value)
#    5476         except AttributeError:
#    5477             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# /usr/local/Cellar/jupyterlab/3.0.7/libexec/lib/python3.9/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     667     def _set_axis(self, axis: int, labels: Index) -> None:
#     668         labels = ensure_index(labels)
# ...

# %%
boston
# Out:
#      0.00632  18.00   2.310  0  0.5380  6.5750  65.20  4.0900   1  296.0  15.30 396.90   4.98  24.00
# 0     0.02731   0.00   7.070  0  0.4690  6.4210  78...
# 1     0.02729   0.00   7.070  0  0.4690  7.1850  61...
# 2     0.03237   0.00   2.180  0  0.4580  6.9980  45...
# 3     0.06905   0.00   2.180  0  0.4580  7.1470  54...
# 4     0.02985   0.00   2.180  0  0.4580  6.4300  58...
# ..                                                 ...
# 500   0.06263   0.00  11.930  0  0.5730  6.5930  69...
# 501   0.04527   0.00  11.930  0  0.5730  6.1200  76...
# 502   0.06076   0.00  11.930  0  0.5730  6.9760  91...
# 503   0.10959   0.00  11.930  0  0.5730  6.7940  89...
# 504   0.04741   0.00  11.930  0  0.5730  6.0300  80...
#
# [505 rows x 1 columns]

# %%
boston.rename(columns = ['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT','MEDV'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-e3628d7797b7> in <module>
# ----> 1 boston.rename(columns = ['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT','MEDV'])
#
# /usr/local/Cellar/jupyterlab/3.0.7/libexec/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     310         @wraps(func)
#     311         def wrapper(*args, **kwargs) -> Callable[..., Any]:
# --> 312             return func(*args, **kwargs)
#     313
#     314         kind = inspect.Parameter.POSITIONAL_OR_KEYWORD
#
# /usr/local/Cellar/jupyterlab/3.0.7/libexec/lib/python3.9/site-packages/pandas/core/frame.py in rename(self, mapper, index, columns, axis, copy, inplace, level, errors)
#    4436         4  3  6
#    4437         """
# -> 4438         return super().rename(
#    4439             mapper=mapper,
# ...

# %%
df =pd.DataFrame(boston)

# %%
df.columns = ['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT','MEDV']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-12ac58e8a3b6> in <module>
# ----> 1 df.columns = ['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT','MEDV']
#
# /usr/local/Cellar/jupyterlab/3.0.7/libexec/lib/python3.9/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5473         try:
#    5474             object.__getattribute__(self, name)
# -> 5475             return object.__setattr__(self, name, value)
#    5476         except AttributeError:
#    5477             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# /usr/local/Cellar/jupyterlab/3.0.7/libexec/lib/python3.9/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     667     def _set_axis(self, axis: int, labels: Index) -> None:
#     668         labels = ensure_index(labels)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 505 entries, 0 to 504
# Data columns (total 1 columns):
#  #   Column                                                                                            Non-Null Count  Dtype
# ---  ------                                                                                            --------------  -----
#  0    0.00632  18.00   2.310  0  0.5380  6.5750  65.20  4.0900   1  296.0  15.30 396.90   4.98  24.00  505 non-null    object
# dtypes: object(1)
# memory usage: 4.1+ KB

# %%
pip install -U scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
from sklearn.cross_validation import train_test_split
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-ea24c5b8272e> in <module>
#       2 import numpy as np
#       3 from sklearn import linear_model
# ----> 4 from sklearn.cross_validation import train_test_split
#
# ModuleNotFoundError: No module named 'sklearn.cross_validation'

# %%
boston = pd.read_csv('./housing.csv')

# %%
boston
# Out:
#      0.00632  18.00   2.310  0  0.5380  6.5750  65.20  4.0900   1  296.0  15.30 396.90   4.98  24.00
# 0     0.02731   0.00   7.070  0  0.4690  6.4210  78...
# 1     0.02729   0.00   7.070  0  0.4690  7.1850  61...
# 2     0.03237   0.00   2.180  0  0.4580  6.9980  45...
# 3     0.06905   0.00   2.180  0  0.4580  7.1470  54...
# 4     0.02985   0.00   2.180  0  0.4580  6.4300  58...
# ..                                                 ...
# 500   0.06263   0.00  11.930  0  0.5730  6.5930  69...
# 501   0.04527   0.00  11.930  0  0.5730  6.1200  76...
# 502   0.06076   0.00  11.930  0  0.5730  6.9760  91...
# 503   0.10959   0.00  11.930  0  0.5730  6.7940  89...
# 504   0.04741   0.00  11.930  0  0.5730  6.0300  80...
#
# [505 rows x 1 columns]

# %%
boston = pd.read_csv('./housing.csv',sep='\t')

# %%
boston
# Out:
#      0.00632  18.00   2.310  0  0.5380  6.5750  65.20  4.0900   1  296.0  15.30 396.90   4.98  24.00
# 0     0.02731   0.00   7.070  0  0.4690  6.4210  78...
# 1     0.02729   0.00   7.070  0  0.4690  7.1850  61...
# 2     0.03237   0.00   2.180  0  0.4580  6.9980  45...
# 3     0.06905   0.00   2.180  0  0.4580  7.1470  54...
# 4     0.02985   0.00   2.180  0  0.4580  6.4300  58...
# ..                                                 ...
# 500   0.06263   0.00  11.930  0  0.5730  6.5930  69...
# 501   0.04527   0.00  11.930  0  0.5730  6.1200  76...
# 502   0.06076   0.00  11.930  0  0.5730  6.9760  91...
# 503   0.10959   0.00  11.930  0  0.5730  6.7940  89...
# 504   0.04741   0.00  11.930  0  0.5730  6.0300  80...
#
# [505 rows x 1 columns]

# %%
boston = pd.read_csv('./housing.csv')

# %%
boston
# Out:
#      0.00632  18.00   2.310  0  0.5380  6.5750  65.20  4.0900   1  296.0  15.30 396.90   4.98  24.00
# 0     0.02731   0.00   7.070  0  0.4690  6.4210  78...
# 1     0.02729   0.00   7.070  0  0.4690  7.1850  61...
# 2     0.03237   0.00   2.180  0  0.4580  6.9980  45...
# 3     0.06905   0.00   2.180  0  0.4580  7.1470  54...
# 4     0.02985   0.00   2.180  0  0.4580  6.4300  58...
# ..                                                 ...
# 500   0.06263   0.00  11.930  0  0.5730  6.5930  69...
# 501   0.04527   0.00  11.930  0  0.5730  6.1200  76...
# 502   0.06076   0.00  11.930  0  0.5730  6.9760  91...
# 503   0.10959   0.00  11.930  0  0.5730  6.7940  89...
# 504   0.04741   0.00  11.930  0  0.5730  6.0300  80...
#
# [505 rows x 1 columns]

# %%
boston = pd.read_csv('./housing.csv',sep=" ", error_bad_lines=False)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-9-7b26f9ec74cd> in <module>
# ----> 1 boston = pd.read_csv('./housing.csv',sep=" ")
#
# /usr/local/Cellar/jupyterlab/3.0.7/libexec/lib/python3.9/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
# ...

# %%
boston = pd.read_csv('./housing.csv',sep=" ", error_bad_lines=False)
# Out:
# b'Skipping line 42: expected 31 fields, saw 32\nSkipping line 43: expected 31 fields, saw 32\nSkipping line 44: expected 31 fields, saw 32\n'

# %%
boston = pd.read_csv('./housing.csv',sep=" ")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-11-7b26f9ec74cd> in <module>
# ----> 1 boston = pd.read_csv('./housing.csv',sep=" ")
#
# /usr/local/Cellar/jupyterlab/3.0.7/libexec/lib/python3.9/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
# ...

# %%
boston = pd.read_csv('./housing.csv',sep=" ",skiprows=1)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-12-7b26f9ec74cd> in <module>
# ----> 1 boston = pd.read_csv('./housing.csv',sep=" ")
#
# /usr/local/Cellar/jupyterlab/3.0.7/libexec/lib/python3.9/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
# ...

# %%
boston = pd.read_csv('./housing.csv',sep=" ",skiprows=1)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-13-6f34f10b135d> in <module>
# ----> 1 boston = pd.read_csv('./housing.csv',sep=" ",skiprows=1)
#
# /usr/local/Cellar/jupyterlab/3.0.7/libexec/lib/python3.9/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
# ...

# %%
b = pd.read_csv('./housing.csv',sep='\t')

# %%
b
# Out:
#      0.00632  18.00   2.310  0  0.5380  6.5750  65.20  4.0900   1  296.0  15.30 396.90   4.98  24.00
# 0     0.02731   0.00   7.070  0  0.4690  6.4210  78...
# 1     0.02729   0.00   7.070  0  0.4690  7.1850  61...
# 2     0.03237   0.00   2.180  0  0.4580  6.9980  45...
# 3     0.06905   0.00   2.180  0  0.4580  7.1470  54...
# 4     0.02985   0.00   2.180  0  0.4580  6.4300  58...
# ..                                                 ...
# 500   0.06263   0.00  11.930  0  0.5730  6.5930  69...
# 501   0.04527   0.00  11.930  0  0.5730  6.1200  76...
# 502   0.06076   0.00  11.930  0  0.5730  6.9760  91...
# 503   0.10959   0.00  11.930  0  0.5730  6.7940  89...
# 504   0.04741   0.00  11.930  0  0.5730  6.0300  80...
#
# [505 rows x 1 columns]

# %%
c = pd.read_csv('./housing.csv',sep=" ")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-16-a4d17aef57f5> in <module>
# ----> 1 c = pd.read_csv('./housing.csv',sep=" ")
#
# /usr/local/Cellar/jupyterlab/3.0.7/libexec/lib/python3.9/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
# ...

# %%
d = pd.read_csv('./housing.csv')

# %%
d
# Out:
#      0.00632  18.00   2.310  0  0.5380  6.5750  65.20  4.0900   1  296.0  15.30 396.90   4.98  24.00
# 0     0.02731   0.00   7.070  0  0.4690  6.4210  78...
# 1     0.02729   0.00   7.070  0  0.4690  7.1850  61...
# 2     0.03237   0.00   2.180  0  0.4580  6.9980  45...
# 3     0.06905   0.00   2.180  0  0.4580  7.1470  54...
# 4     0.02985   0.00   2.180  0  0.4580  6.4300  58...
# ..                                                 ...
# 500   0.06263   0.00  11.930  0  0.5730  6.5930  69...
# 501   0.04527   0.00  11.930  0  0.5730  6.1200  76...
# 502   0.06076   0.00  11.930  0  0.5730  6.9760  91...
# 503   0.10959   0.00  11.930  0  0.5730  6.7940  89...
# 504   0.04741   0.00  11.930  0  0.5730  6.0300  80...
#
# [505 rows x 1 columns]

# %%
d = pd.read_csv('./housing.csv'," ",name=['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT','MEDV'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-7dce3dbf778b> in <module>
# ----> 1 d = pd.read_csv('./housing.csv'," ",name=['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT','MEDV'])
#
# TypeError: read_csv() got an unexpected keyword argument 'name'

# %%
d = pd.read_csv('./housing.csv'," ",names=['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT','MEDV'])

# %%
d
# Out:
#                                                                                      CRIM  \
# NaN 0.00632 NaN 18.0 NaN NaN 2.31  NaN  0.0 NaN 0.538 NaN   6.575 NaN   65.2 NaN   4.0900
#     0.02731 NaN NaN  0.0 NaN NaN   7.07 NaN 0.0 NaN   0.469 NaN   6.421 NaN  78.9     NaN
#     0.02729 NaN NaN  0.0 NaN NaN   7.07 NaN 0.0 NaN   0.469 NaN   7.185 NaN  61.1     NaN
#     0.03237 NaN NaN  0.0 NaN NaN   2.18 NaN 0.0 NaN   0.458 NaN   6.998 NaN  45.8     NaN
#     0.06905 NaN NaN  0.0 NaN NaN   2.18 NaN 0.0 NaN   0.458 NaN   7.147 NaN  54.2     NaN
# ...                                                                                   ...
#     0.06263 NaN NaN  0.0 NaN 11.93 NaN  0.0 NaN 0.573 NaN   6.593 NaN   69.1 NaN   2.4786
#     0.04527 NaN NaN  0.0 NaN 11.93 NaN  0.0 NaN 0.573 NaN   6.120 NaN   76.7 NaN   2.2875
#     0.06076 NaN NaN  0.0 NaN 11.93 NaN  0.0 NaN 0.573 NaN   6.976 NaN   91.0 NaN   2.1675
# ...

# %%
d = pd.read_csv('./housing.csv',names=['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT','MEDV'])

# %%
d
# Out:
#                                                   CRIM  ZN  INDUS  CHAS  NOX  \
# 0     0.00632  18.00   2.310  0  0.5380  6.5750  65... NaN    NaN   NaN  NaN
# 1     0.02731   0.00   7.070  0  0.4690  6.4210  78... NaN    NaN   NaN  NaN
# 2     0.02729   0.00   7.070  0  0.4690  7.1850  61... NaN    NaN   NaN  NaN
# 3     0.03237   0.00   2.180  0  0.4580  6.9980  45... NaN    NaN   NaN  NaN
# 4     0.06905   0.00   2.180  0  0.4580  7.1470  54... NaN    NaN   NaN  NaN
# ..                                                 ...  ..    ...   ...  ...
# 501   0.06263   0.00  11.930  0  0.5730  6.5930  69... NaN    NaN   NaN  NaN
# 502   0.04527   0.00  11.930  0  0.5730  6.1200  76... NaN    NaN   NaN  NaN
# 503   0.06076   0.00  11.930  0  0.5730  6.9760  91... NaN    NaN   NaN  NaN
# 504   0.10959   0.00  11.930  0  0.5730  6.7940  89... NaN    NaN   NaN  NaN
# 505   0.04741   0.00  11.930  0  0.5730  6.0300  80... NaN    NaN   NaN  NaN
#
# ...

# %%
d = pd.read_csv('./housing.csv',skiprows=1,names=['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT','MEDV'])

# %%
d
# Out:
#                                                   CRIM  ZN  INDUS  CHAS  NOX  \
# 0     0.02731   0.00   7.070  0  0.4690  6.4210  78... NaN    NaN   NaN  NaN
# 1     0.02729   0.00   7.070  0  0.4690  7.1850  61... NaN    NaN   NaN  NaN
# 2     0.03237   0.00   2.180  0  0.4580  6.9980  45... NaN    NaN   NaN  NaN
# 3     0.06905   0.00   2.180  0  0.4580  7.1470  54... NaN    NaN   NaN  NaN
# 4     0.02985   0.00   2.180  0  0.4580  6.4300  58... NaN    NaN   NaN  NaN
# ..                                                 ...  ..    ...   ...  ...
# 500   0.06263   0.00  11.930  0  0.5730  6.5930  69... NaN    NaN   NaN  NaN
# 501   0.04527   0.00  11.930  0  0.5730  6.1200  76... NaN    NaN   NaN  NaN
# 502   0.06076   0.00  11.930  0  0.5730  6.9760  91... NaN    NaN   NaN  NaN
# 503   0.10959   0.00  11.930  0  0.5730  6.7940  89... NaN    NaN   NaN  NaN
# 504   0.04741   0.00  11.930  0  0.5730  6.0300  80... NaN    NaN   NaN  NaN
#
# ...

# %%
d = pd.read_csv('./housing.csv',sep="\t",names=['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT','MEDV'])

# %%
d
# Out:
#                                                   CRIM  ZN  INDUS  CHAS  NOX  \
# 0     0.00632  18.00   2.310  0  0.5380  6.5750  65... NaN    NaN   NaN  NaN
# 1     0.02731   0.00   7.070  0  0.4690  6.4210  78... NaN    NaN   NaN  NaN
# 2     0.02729   0.00   7.070  0  0.4690  7.1850  61... NaN    NaN   NaN  NaN
# 3     0.03237   0.00   2.180  0  0.4580  6.9980  45... NaN    NaN   NaN  NaN
# 4     0.06905   0.00   2.180  0  0.4580  7.1470  54... NaN    NaN   NaN  NaN
# ..                                                 ...  ..    ...   ...  ...
# 501   0.06263   0.00  11.930  0  0.5730  6.5930  69... NaN    NaN   NaN  NaN
# 502   0.04527   0.00  11.930  0  0.5730  6.1200  76... NaN    NaN   NaN  NaN
# 503   0.06076   0.00  11.930  0  0.5730  6.9760  91... NaN    NaN   NaN  NaN
# 504   0.10959   0.00  11.930  0  0.5730  6.7940  89... NaN    NaN   NaN  NaN
# 505   0.04741   0.00  11.930  0  0.5730  6.0300  80... NaN    NaN   NaN  NaN
#
# ...

# %%
d = pd.read_csv('./housing.csv',sep=" ",names=['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT','MEDV'])

# %%
d
# Out:
#                                                                                      CRIM  \
# NaN 0.00632 NaN 18.0 NaN NaN 2.31  NaN  0.0 NaN 0.538 NaN   6.575 NaN   65.2 NaN   4.0900
#     0.02731 NaN NaN  0.0 NaN NaN   7.07 NaN 0.0 NaN   0.469 NaN   6.421 NaN  78.9     NaN
#     0.02729 NaN NaN  0.0 NaN NaN   7.07 NaN 0.0 NaN   0.469 NaN   7.185 NaN  61.1     NaN
#     0.03237 NaN NaN  0.0 NaN NaN   2.18 NaN 0.0 NaN   0.458 NaN   6.998 NaN  45.8     NaN
#     0.06905 NaN NaN  0.0 NaN NaN   2.18 NaN 0.0 NaN   0.458 NaN   7.147 NaN  54.2     NaN
# ...                                                                                   ...
#     0.06263 NaN NaN  0.0 NaN 11.93 NaN  0.0 NaN 0.573 NaN   6.593 NaN   69.1 NaN   2.4786
#     0.04527 NaN NaN  0.0 NaN 11.93 NaN  0.0 NaN 0.573 NaN   6.120 NaN   76.7 NaN   2.2875
#     0.06076 NaN NaN  0.0 NaN 11.93 NaN  0.0 NaN 0.573 NaN   6.976 NaN   91.0 NaN   2.1675
# ...

# %%
data = pd.read_csv('housing.csv', header=None, skiprows=[0])

# %%
data
# Out:
#                                                      0
# 0     0.02731   0.00   7.070  0  0.4690  6.4210  78...
# 1     0.02729   0.00   7.070  0  0.4690  7.1850  61...
# 2     0.03237   0.00   2.180  0  0.4580  6.9980  45...
# 3     0.06905   0.00   2.180  0  0.4580  7.1470  54...
# 4     0.02985   0.00   2.180  0  0.4580  6.4300  58...
# ..                                                 ...
# 500   0.06263   0.00  11.930  0  0.5730  6.5930  69...
# 501   0.04527   0.00  11.930  0  0.5730  6.1200  76...
# 502   0.06076   0.00  11.930  0  0.5730  6.9760  91...
# 503   0.10959   0.00  11.930  0  0.5730  6.7940  89...
# 504   0.04741   0.00  11.930  0  0.5730  6.0300  80...
#
# [505 rows x 1 columns]

# %%
data = pd.read_csv('housing.csv', header=None, skiprows=[0],names=['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT','MEDV'])

# %%
data1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-6e25229a93f2> in <module>
# ----> 1 data1
#
# NameError: name 'data1' is not defined

# %%
data
# Out:
#                                                   CRIM  ZN  INDUS  CHAS  NOX  \
# 0     0.02731   0.00   7.070  0  0.4690  6.4210  78... NaN    NaN   NaN  NaN
# 1     0.02729   0.00   7.070  0  0.4690  7.1850  61... NaN    NaN   NaN  NaN
# 2     0.03237   0.00   2.180  0  0.4580  6.9980  45... NaN    NaN   NaN  NaN
# 3     0.06905   0.00   2.180  0  0.4580  7.1470  54... NaN    NaN   NaN  NaN
# 4     0.02985   0.00   2.180  0  0.4580  6.4300  58... NaN    NaN   NaN  NaN
# ..                                                 ...  ..    ...   ...  ...
# 500   0.06263   0.00  11.930  0  0.5730  6.5930  69... NaN    NaN   NaN  NaN
# 501   0.04527   0.00  11.930  0  0.5730  6.1200  76... NaN    NaN   NaN  NaN
# 502   0.06076   0.00  11.930  0  0.5730  6.9760  91... NaN    NaN   NaN  NaN
# 503   0.10959   0.00  11.930  0  0.5730  6.7940  89... NaN    NaN   NaN  NaN
# 504   0.04741   0.00  11.930  0  0.5730  6.0300  80... NaN    NaN   NaN  NaN
#
# ...

# %%
data = pd.read_csv('housing.csv',names=['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT','MEDV'])

# %%
data
# Out:
#                                                                                            CRIM  \
# NaN 0.02731 NaN NaN 0.0 NaN NaN   7.07 NaN 0.0 NaN   0.469 NaN   6.421 NaN  78.9 NaN     4.9671
#     0.02729 NaN NaN 0.0 NaN NaN   7.07 NaN 0.0 NaN   0.469 NaN   7.185 NaN  61.1 NaN     4.9671
#     0.03237 NaN NaN 0.0 NaN NaN   2.18 NaN 0.0 NaN   0.458 NaN   6.998 NaN  45.8 NaN     6.0622
#     0.06905 NaN NaN 0.0 NaN NaN   2.18 NaN 0.0 NaN   0.458 NaN   7.147 NaN  54.2 NaN     6.0622
#     0.02985 NaN NaN 0.0 NaN NaN   2.18 NaN 0.0 NaN   0.458 NaN   6.430 NaN  58.7 NaN     6.0622
# ...                                                                                         ...
#     0.06263 NaN NaN 0.0 NaN 11.93 NaN  0.0 NaN 0.573 NaN   6.593 NaN   69.1 NaN  2.4786     NaN
#     0.04527 NaN NaN 0.0 NaN 11.93 NaN  0.0 NaN 0.573 NaN   6.120 NaN   76.7 NaN  2.2875     NaN
#     0.06076 NaN NaN 0.0 NaN 11.93 NaN  0.0 NaN 0.573 NaN   6.976 NaN   91.0 NaN  2.1675     NaN
# ...

# %%
data = pd.read_csv('housing.csv',sep=" ",header=None)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-38-aeb1c36fb1b9> in <module>
# ----> 1 data = pd.read_csv('housing.csv',sep=" ")
#
# /usr/local/Cellar/jupyterlab/3.0.7/libexec/lib/python3.9/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
# ...

# %%
data = pd.read_csv('housing.csv',sep=" ",header=None)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-39-f14a03149aea> in <module>
# ----> 1 data = pd.read_csv('housing.csv',sep=" ",header=None)
#
# /usr/local/Cellar/jupyterlab/3.0.7/libexec/lib/python3.9/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
# ...

# %%
data = pd.read_csv('housing.csv',header=None)

# %%
data
# Out:
#                                                      0
# 0     0.00632  18.00   2.310  0  0.5380  6.5750  65...
# 1     0.02731   0.00   7.070  0  0.4690  6.4210  78...
# 2     0.02729   0.00   7.070  0  0.4690  7.1850  61...
# 3     0.03237   0.00   2.180  0  0.4580  6.9980  45...
# 4     0.06905   0.00   2.180  0  0.4580  7.1470  54...
# ..                                                 ...
# 501   0.06263   0.00  11.930  0  0.5730  6.5930  69...
# 502   0.04527   0.00  11.930  0  0.5730  6.1200  76...
# 503   0.06076   0.00  11.930  0  0.5730  6.9760  91...
# 504   0.10959   0.00  11.930  0  0.5730  6.7940  89...
# 505   0.04741   0.00  11.930  0  0.5730  6.0300  80...
#
# [506 rows x 1 columns]

# %%
data = pd.read_csv('housing.csv',names=['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT','MEDV'])

# %%
data
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
boston_df = pd.DataFrame(data);

# %%
boston_df.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.distplot(boston['MEDV'], bins=30)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-7fe1b10ad90a> in <module>
# ----> 1 sns.set(rc={'figure.figsize':(11.7,8.27)})
#       2 sns.distplot(boston['MEDV'], bins=30)
#       3 plt.show()
#
# NameError: name 'sns' is not defined

# %%
import seaborn as sns
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.distplot(boston['MEDV'], bins=30)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/Cellar/jupyterlab/3.0.7/libexec/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'MEDV'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-47-d2e0c06301c9> in <module>
# ...

# %%
boston_df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.distplot(boston_df['MEDV'], bins=30)
plt.show()
# Out:
# /usr/local/Cellar/jupyterlab/3.0.7/libexec/lib/python3.9/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-8fb524a509a4> in <module>
#       1 sns.set(rc={'figure.figsize':(11.7,8.27)})
#       2 sns.distplot(boston_df['MEDV'], bins=30)
# ----> 3 plt.show()
#
# NameError: name 'plt' is not defined

# %%
correlation_matrix = boston.corr().round(2)

# %%
sns.heatmap(data=correlation_matrix, annot=True)
# Out:
# <AxesSubplot:>

# %%
boston_df.columns = self.df.columns.str.lower().str.replace(' ', '_')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-af709371286b> in <module>
# ----> 1 boston_df.columns = self.df.columns.str.lower().str.replace(' ', '_')
#
# NameError: name 'self' is not defined

# %%
boston_df.columns = boston_df.columns.str.lower().str.replace(' ', '_')

# %%
 string_columns = list(boston_df.dtypes[boston_df.dtypes == 'object'].index)

# %%
 for col in string_columns:
            boston_df[col] = boston_df[col].str.lower().str.replace(' ', '_')

# %%
boston_df.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
np random.seed(2)
n=len(boston_df)

n_val = int(0.2*n)
n_test = int(0.2*n)
n_train = n - (n_val+n_test)
idx = np.arrange(n)
